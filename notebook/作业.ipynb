# %% [markdown]
# 作业2：

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../data/ml-latest-small/user_for_movie_ratings_summary.csv",encoding='gbk')
data.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres    imdbId   tmdbId
# 0                             Drama  112792.0   9909.0
# 1  Animation|Children|Drama|Musical   33563.0  11360.0
# 2                          Thriller  117665.0    819.0
# 3  Action|Adventure|Sci-Fi|Thriller   82340.0   1103.0
# 4                             Drama   95765.0  11216.0

# %%
# 1. 隔5行筛选数据
data[::5].head(5)
# Out:
#     userId  movieId  rating   timestamp                                 title  \
# 0        1       31     2.5  1260759144                Dangerous Minds (1995)
# 5        1     1263     NaN  1260759151               Deer Hunter, The (1978)
# 10       1     1371     2.5  1260759135  Star Trek: The Motion Picture (1979)
# 15       1     2193     2.0  1260759198                         Willow (1988)
# 20       2       10     4.0   835355493                      GoldenEye (1995)
#
#                        genres    imdbId   tmdbId
# 0                       Drama  112792.0   9909.0
# 5                   Drama|War   77416.0  11778.0
# 10           Adventure|Sci-Fi   79945.0    152.0
# 15   Action|Adventure|Fantasy   96446.0    847.0
# 20  Action|Adventure|Thriller  113189.0    710.0

# %%
# 2. 进行反转
data[::-1].head(5)
# Out:
#         userId  movieId  rating   timestamp                         title  \
# 100003     671     6565     3.5  1074784724             Seabiscuit (2003)
# 100002     671     6385     2.5  1070979663            Whale Rider (2002)
# 100001     671     6365     4.0  1070940363   Matrix Reloaded, The (2003)
# 100000     671     6269     4.0  1065149201                 Stevie (2002)
# 99999      671     6268     2.5  1065579370  Raising Victor Vargas (2002)
#
#                                        genres    imdbId   tmdbId
# 100003                                  Drama  329575.0   4464.0
# 100002                                  Drama  298228.0   1088.0
# 100001  Action|Adventure|Sci-Fi|Thriller|IMAX  234215.0    604.0
# 100000                            Documentary  334416.0  51927.0
# 99999                    Comedy|Drama|Romance  316188.0  25461.0

# %%
# 3. 筛选用户和时间
data[['userId', 'timestamp']].head(5)
# Out:
#    userId   timestamp
# 0       1  1260759144
# 1       1  1260759179
# 2       1  1260759182
# 3       1  1260759185
# 4       1  1260759205

# %%
# 4. 筛选第一行用户和时间
data.iloc[0][['userId', 'timestamp']]
# Out:
# userId                1
# timestamp    1260759144
# Name: 0, dtype: object

# %%
# 筛选id=19的用户对ID为50 ，52的评分
data[(data['userId'] == 19)& (data.movieId.isin([50,52]))]['rating']
# Out:
# 3130    4.0
# 3131    3.0
# Name: rating, dtype: float64
